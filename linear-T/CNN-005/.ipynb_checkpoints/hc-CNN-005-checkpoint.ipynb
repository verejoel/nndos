# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

from tensorflow import set_random_seed
from keras.callbacks import EarlyStopping

from keras.models import Sequential
# sequential model, for linear stack of NN layers

from keras.layers import Dense, Dropout, Activation, Flatten
# Dense is a standard densely connected NN layer
# Dropout randomly drops a percentage, p, of the neurons from a layer (helps reduce overfitting)

from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
# Convolution layers that help efficiently train image data

from keras.utils import np_utils
# used for transforming data

# read training and testing data
X_train = pd.read_pickle("../training_data/X_train.bz2").values
Y_train = pd.read_pickle("../training_data/Y_train.bz2").values
X_test = pd.read_pickle("../training_data/X_test.bz2").values
Y_test = pd.read_pickle("../training_data/Y_test.bz2").values

p = np.shape(X_train)[0] # number of training data
q = np.shape(X_test)[0] # number of test data

m = np.shape(X_train)[1]/2 # number of (T,cv) data
n = np.shape(Y_train)[1] # dimension of output vector

X_train = np.reshape(X_train, (p, 2, m, 1))
X_test = np.reshape(X_test, (q, 2, m, 1))

# check the loaded data
r = np.random.randint(0,p,5)
print r
for i in r:
    plt.figure(0)
    plt.plot(X_train[i][0],X_train[i][1],'+')
    plt.figure(1)
    plt.plot(Y_train[i])

plt.show()

# preprocess input data

# cv lies in the range [0,1], whereas T is in the range [0.1,300]
# we should feature scale T by dividing by 300 (typical maximum value for real data)

X_train[:,0,:,0] /= 300.
X_test[:,0,:,0] /= 300.
# normalize so values range between 0 and 1

# check the processed data
r = np.random.randint(0,p,5)
print r
for i in r:
    plt.figure(0)
    plt.plot(X_train[i][0],X_train[i][1],'+')
    plt.figure(1)
    plt.plot(Y_train[i])
# Out:
# [ 7528 27834  6182 22671 48495]
# [20508 44914 10047 16326 43506]

# %%
#-----------------------------------------------------------------------------
# Define custom loss functions for regression in Keras 
#-----------------------------------------------------------------------------
#
# REF: https://github.com/keras-team/keras/issues/7947

from keras import backend

# root mean squared error (rmse) for regression
def rmse(y_true, y_pred):
    return backend.sqrt(backend.mean(backend.square(y_pred - y_true), axis=-1))

# mean squared error (mse) for regression
def mse(y_true, y_pred):
    return backend.mean(backend.square(y_pred - y_true), axis=-1)

# coefficient of determination (R^2) for regression
def r_square(y_true, y_pred):
    SS_res =  backend.sum(backend.square(y_true - y_pred)) 
    SS_tot = backend.sum(backend.square(y_true - backend.mean(y_true))) 
    return (1 - SS_res/(SS_tot + backend.epsilon()))

def r_square_loss(y_true, y_pred):
    SS_res =  backend.sum(backend.square(y_true - y_pred)) 
    SS_tot = backend.sum(backend.square(y_true - backend.mean(y_true))) 
    return 1 - ( 1 - SS_res/(SS_tot + backend.epsilon()))

# %%
# custom loss function
#
# minimizes difference in output dos and in calculated heat capacity
#
# boltzmann constant in meV per Kelvin
kB = 0.08617

# phonon DOS properties (units are meV)
n = 240 # length of output array
wmax = 120 # ouput spectra will cover range [dw, wmax]
dw = wmax/(1.*n) # spectrum bin width

# temperature vector properties (units are Kelvin)
m = 300 # length of temperature array
Tmin = 1 # minimum temp
Tmax = 300 # maximum temp

def makeT(m):
    return np.linspace(Tmin, Tmax, m)

def makeW(n):
    return np.linspace(dw, wmax, n)

def kernelFunction(w, T):
    y = np.outer(1/T/kB, w) # m x n matrix
    return y*y*np.exp(-y)/(np.exp(-y)-1)**2

w = makeW(n)
T = makeT(m)
kernel = backend.variable(np.array([kernelFunction(w,T) for i in range(32)]))

def customLoss(y_true, y_pred):
    cV_true = backend.batch_dot(kernel, y_true)
    cV_pred = backend.batch_dot(kernel, y_pred)
    return mse(y_true, y_pred) + mse(cV_true, cV_pred)

# %%
a = backend.placeholder((32,240))
b = backend.placeholder((32,300,240))
c = backend.batch_dot(b,a)
mse(c,c)
mse(a,a)+mse(c,c)
c
# Out:
# <tf.Tensor 'Squeeze_8:0' shape=(32, 300) dtype=float32>

# %%
# set random seeds for repeatable behaviour
np.random.seed(140590)
set_random_seed(140590)

# here we define the model architecture
model = Sequential()

#input layer
model.add(Conv2D(1, (2, 2), input_shape=(2, m, 1)))
model.add(BatchNormalization())
model.add(Activation('relu'))
print model.output_shape

model.add(Flatten())
print model.output_shape

model.add(Dense(240,activation='relu'))
model.add(Dropout(0.5))
print model.output_shape

model.add(Dense(n, activation='softmax'))
print model.output_shape
# Out:
# (None, 1, 299, 1)
# (None, 299)
# (None, 240)
# (None, 240)

# %%
# here we compile the model and define a loss function
model.compile(loss='mean_squared_error', optimizer='Nadam', metrics=['mean_squared_error', r_square])

# %%
# enabling early stopping based on mean_squared_error
earlystopping = EarlyStopping(monitor='mean_squared_error', patience=10, verbose=1, mode='auto')

# %%
# now we can fit the model
result = model.fit(X_train, Y_train, batch_size=32, epochs=240, verbose=1, validation_data=(X_test, Y_test), callbacks=[earlystopping])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/240
# 60000/60000 [==============================] - 18s 297us/step - loss: 2.0325e-05 - mean_squared_error: 2.0325e-05 - r_square: 0.6146 - val_loss: 1.5829e-05 - val_mean_squared_error: 1.5829e-05 - val_r_square: 0.6998
# Epoch 2/240
# 60000/60000 [==============================] - 17s 284us/step - loss: 1.9236e-05 - mean_squared_error: 1.9236e-05 - r_square: 0.6352 - val_loss: 1.6015e-05 - val_mean_squared_error: 1.6015e-05 - val_r_square: 0.6974
# Epoch 3/240
# 60000/60000 [==============================] - 17s 278us/step - loss: 1.8711e-05 - mean_squared_error: 1.8711e-05 - r_square: 0.6456 - val_loss: 1.5899e-05 - val_mean_squared_error: 1.5899e-05 - val_r_square: 0.6992
# Epoch 4/240
# 60000/60000 [==============================] - 17s 290us/step - loss: 1.8640e-05 - mean_squared_error: 1.8640e-05 - r_square: 0.6471 - val_loss: 1.5467e-05 - val_mean_squared_error: 1.5467e-05 - val_r_square: 0.7074
# Epoch 5/240
# 60000/60000 [==============================] - 18s 294us/step - loss: 1.8096e-05 - mean_squared_error: 1.8096e-05 - r_square: 0.6571 - val_loss: 1.4997e-05 - val_mean_squared_error: 1.4997e-05 - val_r_square: 0.7168
# Epoch 6/240
# 60000/60000 [==============================] - 17s 287us/step - loss: 1.7902e-05 - mean_squared_error: 1.7902e-05 - r_square: 0.6614 - val_loss: 1.4308e-05 - val_mean_squared_error: 1.4308e-05 - val_r_square: 0.7305
# Epoch 7/240
# 60000/60000 [==============================] - 17s 292us/step - loss: 1.7738e-05 - mean_squared_error: 1.7738e-05 - r_square: 0.6652 - val_loss: 1.3765e-05 - val_mean_squared_error: 1.3765e-05 - val_r_square: 0.7403
# Epoch 8/240
# 60000/60000 [==============================] - 19s 309us/step - loss: 1.7253e-05 - mean_squared_error: 1.7253e-05 - r_square: 0.6740 - val_loss: 1.3129e-05 - val_mean_squared_error: 1.3129e-05 - val_r_square: 0.7526
# Epoch 9/240
# 60000/60000 [==============================] - 24s 394us/step - loss: 1.7154e-05 - mean_squared_error: 1.7154e-05 - r_square: 0.6759 - val_loss: 1.2626e-05 - val_mean_squared_error: 1.2626e-05 - val_r_square: 0.7619
# Epoch 10/240
# 60000/60000 [==============================] - 22s 368us/step - loss: 1.6868e-05 - mean_squared_error: 1.6868e-05 - r_square: 0.6812 - val_loss: 1.3673e-05 - val_mean_squared_error: 1.3673e-05 - val_r_square: 0.7432
# Epoch 11/240
# 60000/60000 [==============================] - 22s 367us/step - loss: 1.6520e-05 - mean_squared_error: 1.6520e-05 - r_square: 0.6883 - val_loss: 1.2358e-05 - val_mean_squared_error: 1.2358e-05 - val_r_square: 0.7671
# Epoch 12/240
# 60000/60000 [==============================] - 24s 400us/step - loss: 1.6109e-05 - mean_squared_error: 1.6109e-05 - r_square: 0.6959 - val_loss: 1.2233e-05 - val_mean_squared_error: 1.2233e-05 - val_r_square: 0.7688
# Epoch 13/240
# 60000/60000 [==============================] - 22s 360us/step - loss: 1.6068e-05 - mean_squared_error: 1.6068e-05 - r_square: 0.6964 - val_loss: 1.1818e-05 - val_mean_squared_error: 1.1818e-05 - val_r_square: 0.7772
# Epoch 14/240
# 60000/60000 [==============================] - 20s 338us/step - loss: 1.6047e-05 - mean_squared_error: 1.6047e-05 - r_square: 0.6971 - val_loss: 1.2422e-05 - val_mean_squared_error: 1.2422e-05 - val_r_square: 0.7663
# Epoch 15/240
# 60000/60000 [==============================] - 21s 353us/step - loss: 1.5858e-05 - mean_squared_error: 1.5858e-05 - r_square: 0.7007 - val_loss: 1.1958e-05 - val_mean_squared_error: 1.1958e-05 - val_r_square: 0.7741
# Epoch 16/240
# 60000/60000 [==============================] - 20s 341us/step - loss: 1.5559e-05 - mean_squared_error: 1.5559e-05 - r_square: 0.7063 - val_loss: 1.1685e-05 - val_mean_squared_error: 1.1685e-05 - val_r_square: 0.7797
# Epoch 17/240
# 60000/60000 [==============================] - 23s 389us/step - loss: 1.5335e-05 - mean_squared_error: 1.5335e-05 - r_square: 0.7093 - val_loss: 1.1455e-05 - val_mean_squared_error: 1.1455e-05 - val_r_square: 0.7840
# Epoch 18/240
# 60000/60000 [==============================] - 23s 379us/step - loss: 1.5095e-05 - mean_squared_error: 1.5095e-05 - r_square: 0.7138 - val_loss: 1.1244e-05 - val_mean_squared_error: 1.1244e-05 - val_r_square: 0.7878
# Epoch 19/240
# 60000/60000 [==============================] - 23s 389us/step - loss: 1.4971e-05 - mean_squared_error: 1.4971e-05 - r_square: 0.7165 - val_loss: 1.1049e-05 - val_mean_squared_error: 1.1049e-05 - val_r_square: 0.7914
# Epoch 20/240
# 60000/60000 [==============================] - 22s 362us/step - loss: 1.5059e-05 - mean_squared_error: 1.5059e-05 - r_square: 0.7153 - val_loss: 1.1174e-05 - val_mean_squared_error: 1.1174e-05 - val_r_square: 0.7889
# Epoch 21/240
# 60000/60000 [==============================] - 22s 362us/step - loss: 1.5048e-05 - mean_squared_error: 1.5048e-05 - r_square: 0.7145 - val_loss: 1.0964e-05 - val_mean_squared_error: 1.0964e-05 - val_r_square: 0.7933
# Epoch 22/240
# 60000/60000 [==============================] - 21s 353us/step - loss: 1.4963e-05 - mean_squared_error: 1.4963e-05 - r_square: 0.7156 - val_loss: 1.1791e-05 - val_mean_squared_error: 1.1791e-05 - val_r_square: 0.7781
# Epoch 23/240
# 60000/60000 [==============================] - 19s 313us/step - loss: 1.4740e-05 - mean_squared_error: 1.4740e-05 - r_square: 0.7198 - val_loss: 1.1452e-05 - val_mean_squared_error: 1.1452e-05 - val_r_square: 0.7849
# Epoch 24/240
# 60000/60000 [==============================] - 18s 304us/step - loss: 1.4589e-05 - mean_squared_error: 1.4589e-05 - r_square: 0.7214 - val_loss: 1.0659e-05 - val_mean_squared_error: 1.0659e-05 - val_r_square: 0.7985
# Epoch 25/240
# 60000/60000 [==============================] - 18s 308us/step - loss: 1.4663e-05 - mean_squared_error: 1.4663e-05 - r_square: 0.7229 - val_loss: 1.0710e-05 - val_mean_squared_error: 1.0710e-05 - val_r_square: 0.7976
# Epoch 26/240
# 60000/60000 [==============================] - 17s 285us/step - loss: 1.4668e-05 - mean_squared_error: 1.4668e-05 - r_square: 0.7230 - val_loss: 1.0851e-05 - val_mean_squared_error: 1.0851e-05 - val_r_square: 0.7955
# Epoch 27/240
# 60000/60000 [==============================] - 18s 304us/step - loss: 1.4514e-05 - mean_squared_error: 1.4514e-05 - r_square: 0.7239 - val_loss: 1.0952e-05 - val_mean_squared_error: 1.0952e-05 - val_r_square: 0.7932
# Epoch 28/240
# 60000/60000 [==============================] - 19s 312us/step - loss: 1.4495e-05 - mean_squared_error: 1.4495e-05 - r_square: 0.7250 - val_loss: 1.0743e-05 - val_mean_squared_error: 1.0743e-05 - val_r_square: 0.7976
# Epoch 29/240
# 60000/60000 [==============================] - 21s 346us/step - loss: 1.4436e-05 - mean_squared_error: 1.4436e-05 - r_square: 0.7277 - val_loss: 1.0553e-05 - val_mean_squared_error: 1.0553e-05 - val_r_square: 0.8008
# Epoch 30/240
# 60000/60000 [==============================] - 20s 340us/step - loss: 1.4203e-05 - mean_squared_error: 1.4203e-05 - r_square: 0.7288 - val_loss: 1.0654e-05 - val_mean_squared_error: 1.0654e-05 - val_r_square: 0.7990
# Epoch 31/240
# 60000/60000 [==============================] - 20s 338us/step - loss: 1.4426e-05 - mean_squared_error: 1.4426e-05 - r_square: 0.7262 - val_loss: 1.0525e-05 - val_mean_squared_error: 1.0525e-05 - val_r_square: 0.8011
# Epoch 32/240
# 60000/60000 [==============================] - 21s 350us/step - loss: 1.4402e-05 - mean_squared_error: 1.4402e-05 - r_square: 0.7263 - val_loss: 1.0522e-05 - val_mean_squared_error: 1.0522e-05 - val_r_square: 0.8015
# Epoch 33/240
# 60000/60000 [==============================] - 19s 321us/step - loss: 1.4242e-05 - mean_squared_error: 1.4242e-05 - r_square: 0.7286 - val_loss: 1.0357e-05 - val_mean_squared_error: 1.0357e-05 - val_r_square: 0.8045
# Epoch 34/240
# 60000/60000 [==============================] - 19s 309us/step - loss: 1.4144e-05 - mean_squared_error: 1.4144e-05 - r_square: 0.7310 - val_loss: 1.0016e-05 - val_mean_squared_error: 1.0016e-05 - val_r_square: 0.8108
# Epoch 35/240
# 60000/60000 [==============================] - 19s 311us/step - loss: 1.4076e-05 - mean_squared_error: 1.4076e-05 - r_square: 0.7314 - val_loss: 1.0184e-05 - val_mean_squared_error: 1.0184e-05 - val_r_square: 0.8077
# Epoch 36/240
# 60000/60000 [==============================] - 17s 276us/step - loss: 1.4228e-05 - mean_squared_error: 1.4228e-05 - r_square: 0.7302 - val_loss: 1.0437e-05 - val_mean_squared_error: 1.0437e-05 - val_r_square: 0.8030
# Epoch 37/240
# 60000/60000 [==============================] - 16s 275us/step - loss: 1.3993e-05 - mean_squared_error: 1.3993e-05 - r_square: 0.7327 - val_loss: 1.0499e-05 - val_mean_squared_error: 1.0499e-05 - val_r_square: 0.8021
# Epoch 38/240
# 60000/60000 [==============================] - 17s 278us/step - loss: 1.4109e-05 - mean_squared_error: 1.4109e-05 - r_square: 0.7323 - val_loss: 1.0089e-05 - val_mean_squared_error: 1.0089e-05 - val_r_square: 0.8096
# Epoch 39/240
# 60000/60000 [==============================] - 17s 277us/step - loss: 1.3993e-05 - mean_squared_error: 1.3993e-05 - r_square: 0.7349 - val_loss: 1.0555e-05 - val_mean_squared_error: 1.0555e-05 - val_r_square: 0.8009
# Epoch 40/240
# 60000/60000 [==============================] - 17s 276us/step - loss: 1.3831e-05 - mean_squared_error: 1.3831e-05 - r_square: 0.7354 - val_loss: 1.0197e-05 - val_mean_squared_error: 1.0197e-05 - val_r_square: 0.8073
# Epoch 41/240
# 60000/60000 [==============================] - 17s 279us/step - loss: 1.3991e-05 - mean_squared_error: 1.3991e-05 - r_square: 0.7349 - val_loss: 1.0508e-05 - val_mean_squared_error: 1.0508e-05 - val_r_square: 0.8023
# Epoch 42/240
# 60000/60000 [==============================] - 17s 282us/step - loss: 1.3735e-05 - mean_squared_error: 1.3735e-05 - r_square: 0.7380 - val_loss: 9.9358e-06 - val_mean_squared_error: 9.9358e-06 - val_r_square: 0.8124
# Epoch 43/240
# 60000/60000 [==============================] - 17s 278us/step - loss: 1.3761e-05 - mean_squared_error: 1.3761e-05 - r_square: 0.7367 - val_loss: 9.7986e-06 - val_mean_squared_error: 9.7986e-06 - val_r_square: 0.8147
# Epoch 44/240
# 60000/60000 [==============================] - 17s 284us/step - loss: 1.3902e-05 - mean_squared_error: 1.3902e-05 - r_square: 0.7371 - val_loss: 1.0165e-05 - val_mean_squared_error: 1.0165e-05 - val_r_square: 0.8078
# Epoch 45/240
# 60000/60000 [==============================] - 19s 318us/step - loss: 1.3851e-05 - mean_squared_error: 1.3851e-05 - r_square: 0.7358 - val_loss: 1.0356e-05 - val_mean_squared_error: 1.0356e-05 - val_r_square: 0.8048
# Epoch 46/240
# 60000/60000 [==============================] - 21s 345us/step - loss: 1.3948e-05 - mean_squared_error: 1.3948e-05 - r_square: 0.7349 - val_loss: 9.8670e-06 - val_mean_squared_error: 9.8670e-06 - val_r_square: 0.8136
# Epoch 47/240
# 60000/60000 [==============================] - 26s 427us/step - loss: 1.3651e-05 - mean_squared_error: 1.3651e-05 - r_square: 0.7395 - val_loss: 1.0026e-05 - val_mean_squared_error: 1.0026e-05 - val_r_square: 0.8109
# Epoch 48/240
# 60000/60000 [==============================] - 23s 388us/step - loss: 1.3825e-05 - mean_squared_error: 1.3825e-05 - r_square: 0.7382 - val_loss: 1.0132e-05 - val_mean_squared_error: 1.0132e-05 - val_r_square: 0.8087
# Epoch 49/240
# 60000/60000 [==============================] - 21s 350us/step - loss: 1.3904e-05 - mean_squared_error: 1.3904e-05 - r_square: 0.7367 - val_loss: 9.8673e-06 - val_mean_squared_error: 9.8673e-06 - val_r_square: 0.8134
# Epoch 50/240
# 60000/60000 [==============================] - 22s 372us/step - loss: 1.3719e-05 - mean_squared_error: 1.3719e-05 - r_square: 0.7383 - val_loss: 9.7031e-06 - val_mean_squared_error: 9.7031e-06 - val_r_square: 0.8167
# Epoch 51/240
# 60000/60000 [==============================] - 23s 391us/step - loss: 1.3528e-05 - mean_squared_error: 1.3528e-05 - r_square: 0.7411 - val_loss: 9.9712e-06 - val_mean_squared_error: 9.9712e-06 - val_r_square: 0.8116
# Epoch 52/240
# 60000/60000 [==============================] - 26s 427us/step - loss: 1.3400e-05 - mean_squared_error: 1.3400e-05 - r_square: 0.7444 - val_loss: 1.0004e-05 - val_mean_squared_error: 1.0004e-05 - val_r_square: 0.8109
# Epoch 53/240
# 60000/60000 [==============================] - 26s 433us/step - loss: 1.3401e-05 - mean_squared_error: 1.3401e-05 - r_square: 0.7443 - val_loss: 1.0750e-05 - val_mean_squared_error: 1.0750e-05 - val_r_square: 0.7981
# Epoch 54/240
# 60000/60000 [==============================] - 29s 476us/step - loss: 1.3320e-05 - mean_squared_error: 1.3320e-05 - r_square: 0.7455 - val_loss: 9.7070e-06 - val_mean_squared_error: 9.7070e-06 - val_r_square: 0.8167
# Epoch 55/240
# 60000/60000 [==============================] - 24s 402us/step - loss: 1.3639e-05 - mean_squared_error: 1.3639e-05 - r_square: 0.7418 - val_loss: 1.0047e-05 - val_mean_squared_error: 1.0047e-05 - val_r_square: 0.8103
# Epoch 56/240
# 60000/60000 [==============================] - 23s 378us/step - loss: 1.3514e-05 - mean_squared_error: 1.3514e-05 - r_square: 0.7430 - val_loss: 9.4579e-06 - val_mean_squared_error: 9.4579e-06 - val_r_square: 0.8211
# Epoch 57/240
# 60000/60000 [==============================] - 23s 382us/step - loss: 1.3475e-05 - mean_squared_error: 1.3475e-05 - r_square: 0.7429 - val_loss: 9.9981e-06 - val_mean_squared_error: 9.9981e-06 - val_r_square: 0.8110
# Epoch 58/240
# 60000/60000 [==============================] - 22s 371us/step - loss: 1.3666e-05 - mean_squared_error: 1.3666e-05 - r_square: 0.7407 - val_loss: 9.7885e-06 - val_mean_squared_error: 9.7885e-06 - val_r_square: 0.8154
# Epoch 59/240
# 60000/60000 [==============================] - 29s 481us/step - loss: 1.3978e-05 - mean_squared_error: 1.3978e-05 - r_square: 0.7338 - val_loss: 1.0076e-05 - val_mean_squared_error: 1.0076e-05 - val_r_square: 0.8090
# Epoch 60/240
# 60000/60000 [==============================] - 24s 399us/step - loss: 1.3700e-05 - mean_squared_error: 1.3700e-05 - r_square: 0.7382 - val_loss: 1.0315e-05 - val_mean_squared_error: 1.0315e-05 - val_r_square: 0.8056
# Epoch 61/240
# 60000/60000 [==============================] - 27s 446us/step - loss: 1.3901e-05 - mean_squared_error: 1.3901e-05 - r_square: 0.7358 - val_loss: 9.6409e-06 - val_mean_squared_error: 9.6409e-06 - val_r_square: 0.8175
# Epoch 62/240
# 60000/60000 [==============================] - 22s 373us/step - loss: 1.3837e-05 - mean_squared_error: 1.3837e-05 - r_square: 0.7362 - val_loss: 1.0148e-05 - val_mean_squared_error: 1.0148e-05 - val_r_square: 0.8082
# Epoch 63/240
# 60000/60000 [==============================] - 24s 397us/step - loss: 1.3579e-05 - mean_squared_error: 1.3579e-05 - r_square: 0.7403 - val_loss: 1.0073e-05 - val_mean_squared_error: 1.0073e-05 - val_r_square: 0.8096
# Epoch 64/240
# 60000/60000 [==============================] - 23s 379us/step - loss: 1.3717e-05 - mean_squared_error: 1.3717e-05 - r_square: 0.7383 - val_loss: 1.0428e-05 - val_mean_squared_error: 1.0428e-05 - val_r_square: 0.8030
# Epoch 00064: early stopping

# %%
# get predictions
Y_pred = model.predict(X_test)

# %%
# plot training curve for R^2 (beware of scale, starts very low negative)
plt.plot(result.history['r_square'])
plt.plot(result.history['val_r_square'])
plt.title('model R^2')
plt.ylabel('R^2')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
           
# plot training curve for rmse
plt.plot(result.history['mean_squared_error'])
plt.plot(result.history['val_mean_squared_error'])
plt.title('mean_squared_error')
plt.ylabel('mean_squared_error')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# print statistical figures of merit

import sklearn.metrics, math
print("\n")
print("Mean absolute error (MAE):      %f" % sklearn.metrics.mean_absolute_error(Y_test,Y_pred))
print("Mean squared error (MSE):       %f" % sklearn.metrics.mean_squared_error(Y_test,Y_pred))
print("Root mean squared error (RMSE): %f" % math.sqrt(sklearn.metrics.mean_squared_error(Y_test,Y_pred)))
print("R square (R^2):                 %f" % sklearn.metrics.r2_score(Y_test,Y_pred))
# Out:
# Mean absolute error (MAE):      0.001525
# Mean squared error (MSE):       0.000010
# Root mean squared error (RMSE): 0.003229
# R square (R^2):                 0.469588

# %%
i = np.random.randint(0,q)
print i

plt.plot(Y_pred[i])
plt.plot(Y_test[i])
plt.legend(['pred', 'real'], loc='upper right')
plt.show()
# Out:
# 5002

# %%
i = 7746
print i

plt.plot(Y_pred[i])
plt.plot(Y_test[i])
plt.legend(['pred', 'real'], loc='upper right')
plt.axis([0,30,0,0.3])
plt.show()

i = 4160
print i

plt.plot(Y_pred[i])
plt.plot(Y_test[i])
plt.legend(['pred', 'real'], loc='upper right')
plt.axis([0,100,0,0.06])
plt.show()

i = 7606
print i

plt.plot(Y_pred[i])
plt.plot(Y_test[i])
plt.legend(['pred', 'real'], loc='upper right')
plt.axis([0,100,0,0.06])
plt.show()
# Out:
# 7746
# 4160
# 7606

# %%
# save model architecture, weights, training config, and state to HD5 file
model.save('./hc-CNN_005_linear_NAdam_MSE_e064_b32.h5')

# %%
from keras.utils import plot_model
plot_model(model, to_file='model-CNN-005.png')

# %%
T = np.linspace(1,300,300)
w = makeW(240)
i=50
plt.plot(Y_pred[i])
plt.plot(Y_test[i])
plt.legend(['pred', 'real'], loc='upper right')
plt.show()
plt.plot(T,cv(Y_pred[i],T))
dat = X_test[i].reshape((2,128))
plt.plot(dat[0]*300,dat[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-9f8be71935ee> in <module>()
#       6 plt.legend(['pred', 'real'], loc='upper right')
#       7 plt.show()
# ----> 8 plt.plot(T,cv(Y_pred[i],T))
#       9 dat = X_test[i].reshape((2,128))
#      10 plt.plot(dat[0]*300,dat[1])
#
# NameError: name 'cv' is not defined
