# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

from tensorflow import set_random_seed
from keras.callbacks import EarlyStopping

from keras.models import Sequential
# sequential model, for linear stack of NN layers

from keras.layers import Dense, Dropout, Activation, Flatten
# Dense is a standard densely connected NN layer
# Dropout randomly drops a percentage, p, of the neurons from a layer (helps reduce overfitting)

from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
# Convolution layers that help efficiently train image data

from keras.utils import np_utils
# used for transforming data

# read training and testing data
X_train = pd.read_pickle("../training_data/X_train.bz2").values
Y_train = pd.read_pickle("../training_data/Y_train.bz2").values
X_test = pd.read_pickle("../training_data/X_test.bz2").values
Y_test = pd.read_pickle("../training_data/Y_test.bz2").values

p = np.shape(X_train)[0] # number of training data
q = np.shape(X_test)[0] # number of test data

m = np.shape(X_train)[1]/2 # number of (T,cv) data
n = np.shape(Y_train)[1] # dimension of output vector

X_train = np.reshape(X_train, (p, 2, m, 1))
X_test = np.reshape(X_test, (q, 2, m, 1))

# check the loaded data
r = np.random.randint(0,p,5)
print r
for i in r:
    plt.figure(0)
    plt.plot(X_train[i][0],X_train[i][1],'+')
    plt.figure(1)
    plt.plot(Y_train[i])

plt.show()

# preprocess input data

# cv lies in the range [0,1], whereas T is in the range [0.1,300]
# we should feature scale T by dividing by 300 (typical maximum value for real data)

X_train[:,0,:,0] /= 300.
X_test[:,0,:,0] /= 300.
# normalize so values range between 0 and 1

# check the processed data
r = np.random.randint(0,p,5)
print r
for i in r:
    plt.figure(0)
    plt.plot(X_train[i][0],X_train[i][1],'+')
    plt.figure(1)
    plt.plot(Y_train[i])
# Out:
# Using TensorFlow backend.
# [19050 57589 43912 52054 12176]
# [26280 16828  8594 23177 30936]

# %%
#-----------------------------------------------------------------------------
# Define custom loss functions for regression in Keras 
#-----------------------------------------------------------------------------
#
# REF: https://github.com/keras-team/keras/issues/7947

from keras import backend

# root mean squared error (rmse) for regression
def rmse(y_true, y_pred):
    return backend.sqrt(backend.mean(backend.square(y_pred - y_true), axis=-1))

# mean squared error (mse) for regression
def mse(y_true, y_pred):
    return backend.mean(backend.square(y_pred - y_true), axis=-1)

# coefficient of determination (R^2) for regression
def r_square(y_true, y_pred):
    SS_res =  backend.sum(backend.square(y_true - y_pred)) 
    SS_tot = backend.sum(backend.square(y_true - backend.mean(y_true))) 
    return (1 - SS_res/(SS_tot + backend.epsilon()))

def r_square_loss(y_true, y_pred):
    SS_res =  backend.sum(backend.square(y_true - y_pred)) 
    SS_tot = backend.sum(backend.square(y_true - backend.mean(y_true))) 
    return 1 - ( 1 - SS_res/(SS_tot + backend.epsilon()))

# %%
# custom loss function
#
# minimizes difference in output dos and in calculated heat capacity
#
# boltzmann constant in meV per Kelvin
kB = 0.08617

# phonon DOS properties (units are meV)
n = 240 # length of output array
wmax = 120 # ouput spectra will cover range [dw, wmax]
dw = wmax/(1.*n) # spectrum bin width

# temperature vector properties (units are Kelvin)
m = 300 # length of temperature array
Tmin = 1 # minimum temp
Tmax = 300 # maximum temp

def makeT(m):
    return np.linspace(Tmin, Tmax, m)

def makeW(n):
    return np.linspace(dw, wmax, n)

def kernelFunction(w, T):
    y = np.outer(1/T/kB, w) # m x n matrix
    return y*y*np.exp(-y)/(np.exp(-y)-1)**2

w = makeW(n)
T = makeT(m)
kernel = backend.variable(np.array([kernelFunction(w,T) for i in range(32)]))

def customLoss(y_true, y_pred):
    cV_true = backend.batch_dot(kernel, y_true)
    cV_pred = backend.batch_dot(kernel, y_pred)
    a = mse(y_true, y_pred)
    b = mse(cV_true, cV_pred)
    cost = a + b
    return cost

# %%
a = backend.placeholder((32,240))
b = backend.placeholder((32,300,240))
c = backend.batch_dot(b,a)
mse(c,c)
mse(a,a)+mse(c,c)
customLoss(a,a)

# %%
# set random seeds for repeatable behaviour
np.random.seed(140590)
set_random_seed(140590)

# here we define the model architecture
model = Sequential()

#input layer
model.add(Conv2D(4, (2, 2), input_shape=(2, m, 1)))
model.add(BatchNormalization())
model.add(Activation('relu'))
print model.output_shape

model.add(Flatten())
print model.output_shape

model.add(Dense(240,activation='relu'))
model.add(Dropout(0.5))
print model.output_shape

model.add(Dense(n, activation='softmax'))
print model.output_shape
# Out:
# (None, 1, 299, 4)
# (None, 1196)
# (None, 240)
# (None, 240)

# %%
# here we compile the model and define a loss function
model.compile(loss='mean_squared_error', optimizer='Nadam', metrics=['mean_squared_error', rmse, r_square])

# %%
# enabling early stopping based on mean_squared_error
earlystopping = EarlyStopping(monitor='mean_squared_error', patience=10, verbose=1, mode='auto')

# %%
# now we can fit the model
result = model.fit(X_train, Y_train, batch_size=32, epochs=240, verbose=1, validation_data=(X_test, Y_test), callbacks=[earlystopping])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/240
# 60000/60000 [==============================] - 27s 443us/step - loss: 2.0327e-05 - mean_squared_error: 2.0327e-05 - rmse: 0.0041 - r_square: 0.6172 - val_loss: 1.3345e-05 - val_mean_squared_error: 1.3345e-05 - val_rmse: 0.0033 - val_r_square: 0.7495
# Epoch 2/240
# 60000/60000 [==============================] - 24s 403us/step - loss: 1.5798e-05 - mean_squared_error: 1.5798e-05 - rmse: 0.0036 - r_square: 0.7026 - val_loss: 1.1737e-05 - val_mean_squared_error: 1.1737e-05 - val_rmse: 0.0032 - val_r_square: 0.7792
# Epoch 3/240
# 60000/60000 [==============================] - 25s 419us/step - loss: 1.4809e-05 - mean_squared_error: 1.4809e-05 - rmse: 0.0035 - r_square: 0.7208 - val_loss: 1.0902e-05 - val_mean_squared_error: 1.0902e-05 - val_rmse: 0.0031 - val_r_square: 0.7947
# Epoch 4/240
# 60000/60000 [==============================] - 28s 470us/step - loss: 1.4395e-05 - mean_squared_error: 1.4395e-05 - rmse: 0.0035 - r_square: 0.7288 - val_loss: 1.0409e-05 - val_mean_squared_error: 1.0409e-05 - val_rmse: 0.0030 - val_r_square: 0.8036
# Epoch 5/240
# 60000/60000 [==============================] - 28s 474us/step - loss: 1.4039e-05 - mean_squared_error: 1.4039e-05 - rmse: 0.0034 - r_square: 0.7354 - val_loss: 1.0542e-05 - val_mean_squared_error: 1.0542e-05 - val_rmse: 0.0030 - val_r_square: 0.8011
# Epoch 130/240
# 60000/60000 [==============================] - 16s 267us/step - loss: 1.0903e-05 - mean_squared_error: 1.0903e-05 - rmse: 0.0030 - r_square: 0.7943 - val_loss: 7.2585e-06 - val_mean_squared_error: 7.2585e-06 - val_rmse: 0.0025 - val_r_square: 0.8624
# Epoch 131/240
# 60000/60000 [==============================] - 16s 269us/step - loss: 1.0941e-05 - mean_squared_error: 1.0941e-05 - rmse: 0.0030 - r_square: 0.7930 - val_loss: 7.2022e-06 - val_mean_squared_error: 7.2022e-06 - val_rmse: 0.0025 - val_r_square: 0.8633
# Epoch 132/240
# 60000/60000 [==============================] - 16s 264us/step - loss: 1.0775e-05 - mean_squared_error: 1.0775e-05 - rmse: 0.0030 - r_square: 0.7957 - val_loss: 7.2194e-06 - val_mean_squared_error: 7.2194e-06 - val_rmse: 0.0025 - val_r_square: 0.8630
# Epoch 133/240
# 60000/60000 [==============================] - 16s 267us/step - loss: 1.0867e-05 - mean_squared_error: 1.0867e-05 - rmse: 0.0030 - r_square: 0.7946 - val_loss: 7.4163e-06 - val_mean_squared_error: 7.4163e-06 - val_rmse: 0.0026 - val_r_square: 0.8592
# Epoch 134/240
# 60000/60000 [==============================] - 16s 267us/step - loss: 1.0883e-05 - mean_squared_error: 1.0883e-05 - rmse: 0.0030 - r_square: 0.7945 - val_loss: 6.9461e-06 - val_mean_squared_error: 6.9461e-06 - val_rmse: 0.0025 - val_r_square: 0.8682
# Epoch 135/240
# 60000/60000 [==============================] - 17s 286us/step - loss: 1.0865e-05 - mean_squared_error: 1.0865e-05 - rmse: 0.0030 - r_square: 0.7943 - val_loss: 7.1751e-06 - val_mean_squared_error: 7.1751e-06 - val_rmse: 0.0025 - val_r_square: 0.8637
# Epoch 136/240
# 60000/60000 [==============================] - 18s 293us/step - loss: 1.0817e-05 - mean_squared_error: 1.0817e-05 - rmse: 0.0030 - r_square: 0.7955 - val_loss: 7.3673e-06 - val_mean_squared_error: 7.3673e-06 - val_rmse: 0.0025 - val_r_square: 0.8602
# Epoch 137/240
# 60000/60000 [==============================] - 17s 279us/step - loss: 1.0890e-05 - mean_squared_error: 1.0890e-05 - rmse: 0.0030 - r_square: 0.7946 - val_loss: 7.0504e-06 - val_mean_squared_error: 7.0504e-06 - val_rmse: 0.0025 - val_r_square: 0.8664
# Epoch 138/240
# 60000/60000 [==============================] - 30s 495us/step - loss: 1.0823e-05 - mean_squared_error: 1.0823e-05 - rmse: 0.0030 - r_square: 0.7954 - val_loss: 7.4318e-06 - val_mean_squared_error: 7.4318e-06 - val_rmse: 0.0025 - val_r_square: 0.8594
# Epoch 139/240
# 60000/60000 [==============================] - 22s 367us/step - loss: 1.0799e-05 - mean_squared_error: 1.0799e-05 - rmse: 0.0030 - r_square: 0.7958 - val_loss: 7.2771e-06 - val_mean_squared_error: 7.2771e-06 - val_rmse: 0.0025 - val_r_square: 0.8621
# Epoch 140/240
# 60000/60000 [==============================] - 29s 478us/step - loss: 1.0824e-05 - mean_squared_error: 1.0824e-05 - rmse: 0.0030 - r_square: 0.7949 - val_loss: 7.0310e-06 - val_mean_squared_error: 7.0310e-06 - val_rmse: 0.0025 - val_r_square: 0.8664
# Epoch 141/240
# 60000/60000 [==============================] - 43s 719us/step - loss: 1.0791e-05 - mean_squared_error: 1.0791e-05 - rmse: 0.0030 - r_square: 0.7954 - val_loss: 6.9906e-06 - val_mean_squared_error: 6.9906e-06 - val_rmse: 0.0025 - val_r_square: 0.8673
# Epoch 142/240
# 60000/60000 [==============================] - 31s 517us/step - loss: 1.0814e-05 - mean_squared_error: 1.0814e-05 - rmse: 0.0030 - r_square: 0.7956 - val_loss: 7.1571e-06 - val_mean_squared_error: 7.1571e-06 - val_rmse: 0.0025 - val_r_square: 0.8643
# Epoch 00142: early stopping

# %%
# get predictions
Y_pred = model.predict(X_test)

# %%
# plot training curve for R^2 (beware of scale, starts very low negative)
plt.plot(result.history['r_square'])
plt.plot(result.history['val_r_square'])
plt.title('model R^2')
plt.ylabel('R^2')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
           
# plot training curve for rmse
plt.plot(result.history['rmse'])
plt.plot(result.history['val_rmse'])
plt.title('mean_squared_error')
plt.ylabel('mean_squared_error')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# print statistical figures of merit

import sklearn.metrics, math
print("\n")
print("Mean absolute error (MAE):      %f" % sklearn.metrics.mean_absolute_error(Y_test,Y_pred))
print("Mean squared error (MSE):       %f" % sklearn.metrics.mean_squared_error(Y_test,Y_pred))
print("Root mean squared error (RMSE): %f" % math.sqrt(sklearn.metrics.mean_squared_error(Y_test,Y_pred)))
print("R square (R^2):                 %f" % sklearn.metrics.r2_score(Y_test,Y_pred))
# Out:
# Mean absolute error (MAE):      0.001216
# Mean squared error (MSE):       0.000007
# Root mean squared error (RMSE): 0.002675
# R square (R^2):                 0.664329

# %%
i = np.random.randint(0,q)
print i

plt.plot(Y_pred[i])
plt.plot(Y_test[i])

plt.legend(['pred', 'real'], loc='upper right')
plt.show()
# Out:
# 3313

# %%
i = 2234
print i

plt.plot(Y_pred[i])
plt.plot(Y_test[i])
plt.legend(['pred', 'real'], loc='upper right')
plt.axis([0,40,0,0.15])
plt.show()

i = 4160
print i

plt.plot(Y_pred[i])
plt.plot(Y_test[i])
plt.legend(['pred', 'real'], loc='upper right')
plt.axis([0,100,0,0.06])
plt.show()

i = 7606
print i

plt.plot(Y_pred[i])
plt.plot(Y_test[i])
plt.legend(['pred', 'real'], loc='upper right')
plt.axis([0,100,0,0.06])
plt.show()
# Out:
# 2234
# 4160
# 7606

# %%
# save model architecture, weights, training config, and state to HD5 file
model.save('./hc-CNN_005_linear_NAdam_MSE_e064_b32.h5')

# %%
from keras.utils import plot_model
plot_model(model, to_file='model-CNN-005.png')

# %%
T = np.linspace(1,300,300)
w = makeW(240)
i=50
plt.plot(Y_pred[i])
plt.plot(Y_test[i])
plt.legend(['pred', 'real'], loc='upper right')
plt.show()
plt.plot(T,cv(Y_pred[i],T))
dat = X_test[i].reshape((2,128))
plt.plot(dat[0]*300,dat[1])
